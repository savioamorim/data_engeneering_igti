# %% [markdown]
# # Extrai tweets

# %%
# !pip install tweepy datetime
# Out:
# ...
#      |████████████████████████████████| 60 kB 4.7 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 147 kB 9.5 MB/s eta 0:00:01
# ...

# %% [markdown]
# # Play!

# %%
# !python get_tweets.py
# Out:
# ^C
# Traceback (most recent call last):
#   File "get_tweets.py", line 34, in <module>
#     stream.filter(track=["Trump"])
#   File "/home/savioamorim/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py", line 474, in filter
#     self._start(is_async)
#   File "/home/savioamorim/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py", line 389, in _start
#     self._run()
#   File "/home/savioamorim/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "/home/savioamorim/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py", line 339, in _read_loop
#     line = buf.read_line()
#   File "/home/savioamorim/anaconda3/lib/python3.8/site-packages/tweepy/streaming.py", line 200, in read_line
#     self._buffer += self._stream.read(self._chunk_size)
#   File "/home/savioamorim/anaconda3/lib/python3.8/site-packages/urllib3/response.py", line 518, in read
#     data = self._fp.read(amt) if not fp_closed else b""
# ...

# %% [markdown]
# # Entendendo a estrutura do JSON

# %%
import json

# %%
# Abrir o arquivo de tweets e ler as linhas
with open('collected_tweets2021-03-07-18-34-41.txt', 'r') as file:
    tweets = file.readlines()

# %%
# Fazendo o parse do tweet para um formato json e exporta arquivo
with open('tweet.json', 'w') as f:
    json.dump(
        json.loads(json.loads(tweets[0])),
        f
    )

# %%
json.loads(json.loads(tweets[0]))
# Out:
# {'created_at': 'Sun Mar 07 21:34:37 +0000 2021',
#  'id': 1368676485528088580,
#  'id_str': '1368676485528088580',
#  'text': 'RT @BryanDawsonUSA: The power of the vast right wing disinformation machine:\n\nThe 100 U.S. counties with the highest death rates from #COVI…',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1269378044793241600,
#   'id_str': '1269378044793241600',
#   'name': 'Tasia Surch',
#   'screen_name': 'SurchTasia',
#   'location': 'Rancho Santa Margarita, CA',
#   'url': None,
#   'description': 'Boy Mom, Fur Baby Mom, Loves Democracy',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 240,
#   'friends_count': 528,
#   'listed_count': 0,
# ...

# %%
# Fazendo o parse de todos os tweets
parsed_tweets = [json.loads(json.loads(i)) for i in tweets]

# %%
# Quantidade de tweets coletados
len(parsed_tweets)
# Out:
# 8418

# %% [markdown]
# # Acessando as chaves do JSON (dicionário)

# %%
# Acessar chave de primeiro nível
parsed_tweets[0]["created_at"]
# Out:
# 'Sun Mar 07 21:34:37 +0000 2021'

# %%
# Acessar chaves aninhadas
parsed_tweets[0]["user"]["id"]
# Out:
# 1269378044793241600

# %% [markdown]
# # Transformar os tweets em uma estrutura relacional analisável

# %%
import pandas as pd

# %%
teste = pd.DataFrame(parsed_tweets[0])
teste
# Não funciona!!
# Out:
#                                    created_at                   id  \
# id             Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# id_str         Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# name           Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# screen_name    Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# location       Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# ...                                       ...                  ...
# filter_level   Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# hashtags       Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# urls           Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# user_mentions  Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# symbols        Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
#
#                             id_str  \
# id             1368676485528088580
# id_str         1368676485528088580
# name           1368676485528088580
# ...

# %%
df_tratado = pd.DataFrame(parsed_tweets[0]).reset_index(drop=True).iloc[:1]
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Mar 07 21:34:37 +0000 2021  1368676485528088580  1368676485528088580
#
#                                                 text  \
# 0  RT @BryanDawsonUSA: The power of the vast righ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ... quote_count reply_count retweet_count  \
# 0                    None  ...           0           0             0
#
#   favorite_count entities favorited retweeted  filter_level  lang  \
# 0              0      NaN     False     False           low    en
#
#     timestamp_ms
# 0  1615152877586
#
# [1 rows x 28 columns]

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'quote_count',
#        'reply_count', 'retweet_count', 'favorite_count', 'entities',
#        'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
df_tratado.drop(columns=['quote_count',
                         'reply_count',
                         'retweet_count',
                         'favorite_count',
                         'favorited',
                         'retweeted',
                         'user',
                         'entities',
                         'retweeted_status'], inplace=True) #Mesma coisa de atribuir na variável df_tratado

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'filter_level', 'lang',
#        'timestamp_ms'],
#       dtype='object')

# %%
parsed_tweets[0]["user"]
# Out:
# {'id': 1269378044793241600,
#  'id_str': '1269378044793241600',
#  'name': 'Tasia Surch',
#  'screen_name': 'SurchTasia',
#  'location': 'Rancho Santa Margarita, CA',
#  'url': None,
#  'description': 'Boy Mom, Fur Baby Mom, Loves Democracy',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 240,
#  'friends_count': 528,
#  'listed_count': 0,
#  'favourites_count': 29532,
#  'statuses_count': 6205,
#  'created_at': 'Sat Jun 06 21:18:31 +0000 2020',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': '',
#  'profile_background_image_url_https': '',
#  'profile_background_tile': False,
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
# ...

# %%
df_tratado['user_id'] = parsed_tweets[0]["user"]["id"]
df_tratado['user_id_str'] = parsed_tweets[0]["user"]["id_str"]
df_tratado['user_screen_name'] = parsed_tweets[0]["user"]["screen_name"]
df_tratado['user_location'] = parsed_tweets[0]["user"]["location"]
df_tratado['user_description'] = parsed_tweets[0]["user"]["description"]
df_tratado['user_protected'] = parsed_tweets[0]["user"]["protected"]
df_tratado['user_verified'] = parsed_tweets[0]["user"]["verified"]
df_tratado['user_followers_count'] = parsed_tweets[0]["user"]["followers_count"]
df_tratado['user_friends_count'] = parsed_tweets[0]["user"]["friends_count"]
df_tratado['user_created_at'] = parsed_tweets[0]["user"]["created_at"]

# %%
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Mar 07 21:34:37 +0000 2021  1368676485528088580  1368676485528088580
#
#                                                 text  \
# 0  RT @BryanDawsonUSA: The power of the vast righ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...              user_id          user_id_str  \
# 0                    None  ...  1269378044793241600  1269378044793241600
#
#   user_screen_name               user_location  \
# 0       SurchTasia  Rancho Santa Margarita, CA
#
#                          user_description  user_protected user_verified  \
# 0  Boy Mom, Fur Baby Mom, Loves Democracy           False         False
#
# ...

# %%
# Entidades
parsed_tweets[0]["entities"]
# Out:
# {'hashtags': [],
#  'urls': [],
#  'user_mentions': [{'screen_name': 'BryanDawsonUSA',
#    'name': 'Bryan Dawson',
#    'id': 997682274,
#    'id_str': '997682274',
#    'indices': [3, 18]}],
#  'symbols': []}

# %%
user_mentions = []

for i in range (len(parsed_tweets[0]['entities']['user_mentions'])):
    dicionario_base = parsed_tweets[0]['entities']['user_mentions'][i].copy()
    dicionario_base.pop('indices', None)
    df = pd.DataFrame(dicionario_base, index=[0])
    df = df.rename(columns={
        'screen_name': 'entities_screen_name',
        'name': 'entities_name',
        'id': 'entities_id',
        'id_str': 'entities_id_str'
    })
    user_mentions.append(df)

# %%
user_mentions
# Out:
# [  entities_screen_name entities_name  entities_id entities_id_str
#  0       BryanDawsonUSA  Bryan Dawson    997682274       997682274]

# %%
dfs = []
for i in user_mentions:
    dfs.append(
        pd.concat([df_tratado.copy(), i], axis=1)
    )

# %%
pd.concat(dfs, ignore_index=True)
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Mar 07 21:34:37 +0000 2021  1368676485528088580  1368676485528088580
#
#                                                 text  \
# 0  RT @BryanDawsonUSA: The power of the vast righ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...                        user_description  \
# 0                    None  ...  Boy Mom, Fur Baby Mom, Loves Democracy
#
#   user_protected user_verified user_followers_count user_friends_count  \
# 0          False         False                  240                528
#
#                   user_created_at entities_screen_name entities_name  \
# ...

# %% [markdown]
# Criar uma função que faz todo o tratamento do tweet e converte para um DataFrame Pandas

# %%
def tweet_to_df(tweet):
    try:
        df_tratado = pd.DataFrame(tweet).reset_index(drop=True).iloc[:1]
        df_tratado.drop(columns=['quote_count',
                             'reply_count',
                             'retweet_count',
                             'favorite_count',
                             'favorited',
                             'retweeted',
                             'user',
                             'entities',
                             'retweeted_status'], inplace=True)

        df_tratado['user_id'] = tweet["user"]["id"]
        df_tratado['user_id_str'] = tweet["user"]["id_str"]
        df_tratado['user_screen_name'] = tweet["user"]["screen_name"]
        df_tratado['user_location'] = tweet["user"]["location"]
        df_tratado['user_description'] = tweet["user"]["description"]
        df_tratado['user_protected'] = tweet["user"]["protected"]
        df_tratado['user_verified'] = tweet["user"]["verified"]
        df_tratado['user_followers_count'] = tweet["user"]["followers_count"]
        df_tratado['user_friends_count'] = tweet["user"]["friends_count"]
        df_tratado['user_created_at'] = tweet["user"]["created_at"]

        user_mentions = []
        for i in range (len(tweet['entities']['user_mentions'])):
            dicionario_base = tweet['entities']['user_mentions'][i].copy()
            dicionario_base.pop('indices', None)
            df = pd.DataFrame(dicionario_base, index=[0])
            df = df.rename(columns={
                'screen_name': 'entities_screen_name',
                'name': 'entities_name',
                'id': 'entities_id',
                'id_str': 'entities_id_str'
            })
            user_mentions.append(df)

        dfs = []
        for i in user_mentions:
            dfs.append(
                pd.concat([df_tratado.copy(), i], axis=1)
            )

        df_final = pd.concat(dfs, ignore_index=True)
    except:
        return None
    
    return df_final

# %%
tweet_to_df(parsed_tweets[0])
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Mar 07 21:34:37 +0000 2021  1368676485528088580  1368676485528088580
#
#                                                 text  \
# 0  RT @BryanDawsonUSA: The power of the vast righ...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...                        user_description  \
# 0                    None  ...  Boy Mom, Fur Baby Mom, Loves Democracy
#
#   user_protected user_verified user_followers_count user_friends_count  \
# 0          False         False                  240                528
#
#                   user_created_at entities_screen_name entities_name  \
# ...

# %%
# %%time
# Iterar e transformar todos os tweets
parseados = [tweet_to_df(tweet) for tweet in parsed_tweets]
# Out:
# CPU times: user 1min 14s, sys: 188 ms, total: 1min 15s
# Wall time: 1min 15s

# %%
# Eliminar as posições vazias da lista
parseados = [i for i in parseados if i is not None]

# %%
len(parseados)
# Out:
# 5450

# %%
tratado = pd.concat(parseados, ignore_index=True)

# %%
tratado
# Out:
#                           created_at                   id  \
# 0     Sun Mar 07 21:34:37 +0000 2021  1368676485528088580
# 1     Sun Mar 07 21:34:38 +0000 2021  1368676487931564032
# 2     Sun Mar 07 21:34:38 +0000 2021  1368676488757702659
# 3     Sun Mar 07 21:34:38 +0000 2021  1368676489043050497
# 4     Sun Mar 07 21:34:38 +0000 2021  1368676489512841228
# ...                              ...                  ...
# 6835  Sun Mar 07 21:49:10 +0000 2021  1368680144924147714
# 6836  Sun Mar 07 21:49:10 +0000 2021  1368680145108807682
# 6837  Sun Mar 07 21:49:10 +0000 2021  1368680145356218369
# 6838  Sun Mar 07 21:49:10 +0000 2021  1368680147218554880
# 6839  Sun Mar 07 21:49:10 +0000 2021  1368680147721875460
#
#                    id_str                                               text  \
# 0     1368676485528088580  RT @BryanDawsonUSA: The power of the vast righ...
# 1     1368676487931564032  RT @jsolomonReports: Adviser says Trump has no...
# ...

# %% [markdown]
# # Ingestão de dados do twitter no SQL Server

# %%
import pyodbc
import sqlalchemy
import dotenv
import os

# %%
dotenv.load_dotenv(dotenv.find_dotenv())
user = os.getenv("user")
password = os.getenv("password")

engine = sqlalchemy.create_engine(
    f"mssql+pyodbc://{user}:{password}@127.0.0.1/twitter?driver=ODBC+Driver+17+for+SQL+Server"
)

# %%
# Ingestão
tratado.to_sql("tweets", con=engine, index=False, if_exists='append')
